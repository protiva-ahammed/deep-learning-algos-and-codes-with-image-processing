# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename)

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from matplotlib import pyplot as plt
import math, os, re, warnings, random
from sklearn.utils import class_weight
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import optimizers, applications, Sequential, losses, metrics
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,LearningRateScheduler

# %%
def seed_everything(seed=0):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = "1"
    
    
seed = 0
seed_everything(seed)
warnings.filterwarnings('ignore')
strategy = tf.distribute.get_strategy()
AUTO = tf.data.experimental.AUTOTUNE
REPLICAS = strategy.num_replicas_in_sync 
print('# REPLICAS: {}'.format(REPLICAS))
# Out:
# # REPLICAS: 1

# %%
BATCH_SIZE = 32 * REPLICAS
LEARNING_RATE = 3e-3 * REPLICAS
EPOCHS = 32
HEIGHT = 300
WIDTH = 300
CHANNELS = 3
ES_PATIENCE = 10
AUG_BATCH=BATCH_SIZE
IMAGE_SIZE=[HEIGHT,WIDTH]

# %%
# GCS_PATH = KaggleDatasets().get_gcs_path('leukemia-classification')
GCS_PATH = '../input/leukemia-classification/'

# %%
train_dataset_0_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_0/all/*.bmp')
train_dataset_0_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_0/hem/*.bmp')
train_dataset_1_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_1/all/*.bmp')
train_dataset_1_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_1/hem/*.bmp')
train_dataset_2_all = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_2/all/*.bmp')
train_dataset_2_hem = glob.glob(GCS_PATH + '/C-NMC_Leukemia/training_data/fold_2/hem/*.bmp')

# %%
#len(train_dataset_0_all+train_dataset_0_hem)

# %%
# Include Validation data as well :-

test_data=pd.read_csv(GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

# %%
#for test dataset all and hem ratio
print(len(ATL))#1
print(len(HTL))#0
# Out:
# 1219
# 648

# %%
# Merging here:-

A=[]
H=[]

A.extend(train_dataset_0_all)
A.extend(train_dataset_1_all)
A.extend(train_dataset_2_all)


H.extend(train_dataset_0_hem)
H.extend(train_dataset_1_hem)
H.extend(train_dataset_2_hem)


print(len(A))
print(len(H))

# Create labels :-
Label_A = [1]*len(A)
Label_H = [0]*len(H)

# Converting to pandas dataframe for easier access:-
A.extend(H)
Label_A.extend(Label_H)
df = pd.DataFrame({'path':A, 'label':Label_A})
df = df.sample(frac=1).reset_index(drop=True)

FILENAMES = df['path']
LABELS = df['label']

print('Final Merged Data')
df.head(5)
# Out:
# 7272
# 3389
# Final Merged Data
#                                                 path  label
# 0  ../input/leukemia-classification//C-NMC_Leukem...      1
# 1  ../input/leukemia-classification//C-NMC_Leukem...      1
# 2  ../input/leukemia-classification//C-NMC_Leukem...      0
# 3  ../input/leukemia-classification//C-NMC_Leukem...      0
# 4  ../input/leukemia-classification//C-NMC_Leukem...      1

# %%
from sklearn.utils import compute_class_weight
cw = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique(LABELS),
                                        y = LABELS                                                   
                                    )
cw = {0:cw[0], 1:cw[1]}

cw
# Out:
# {0: 1.5728828562997934, 1: 0.7330170517051705}

# %%
# Define Augmentation function:-
def data_augment(image, label):
    
    p_spatial = tf.random.uniform([], 0, 1.0, dtype=tf.float32)# 0 to 1 floating number
    p_rotate = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    p_pixel = tf.random.uniform([], 0, 1.0, dtype=tf.float32)    
    p_shear = tf.random.uniform([], 0, 1.0, dtype=tf.float32)#break off or cause to break off, owing to a structural strain.
    p_crop = tf.random.uniform([], 0, 1.0, dtype=tf.float32)
    
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_flip_left_right(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    if p_pixel >= .2:
        if p_pixel >= .8:
            image = tf.image.random_saturation(image, lower=.7, upper=1.3)
        elif p_pixel >= .6:
            image = tf.image.random_contrast(image, lower=.8, upper=1.2)
        elif p_pixel >= .4:
            image = tf.image.random_brightness(image, max_delta=.1)
        else:
            image = tf.image.adjust_gamma(image, gamma=.6)
            
    if p_crop > .7:
        if p_crop > .9:
            image = tf.image.central_crop(image, central_fraction=.6)
        elif p_crop > .8:
            image = tf.image.central_crop(image, central_fraction=.7)
        else:
            image = tf.image.central_crop(image, central_fraction=.8)
    elif p_crop > .4:
        crop_size = tf.random.uniform([], int(HEIGHT*.6), HEIGHT, dtype=tf.int32)
        image = tf.image.random_crop(image, size=[crop_size, crop_size, CHANNELS])
        
    image = tf.image.resize(image, size=[HEIGHT, WIDTH])
    image = tf.reshape(image, [HEIGHT, WIDTH, 3])
    
    return image, label
def parse_data(filename,label):
    image = tf.io.read_file(filename)
    image = tf.image.decode_bmp(image)
    image = tf.image.convert_image_dtype(image, tf.float32) /  0.45 
    image = tf.image.resize(image, IMAGE_SIZE)
    return image, tf.one_hot(label,2)

def load_dataset(filenames, labels ,ordered=False):
    ignore_order = tf.data.Options()
    if not ordered:
        ignore_order.experimental_deterministic = False

    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    dataset = dataset.with_options(ignore_order)
    dataset = dataset.map(parse_data, num_parallel_calls=AUTO)
    return dataset

def get_dataset(FILENAMES,LABELS, ordered=False, repeated=False, augment=False):
    dataset = load_dataset(FILENAMES, LABELS, ordered=ordered)
    if augment:
        dataset = dataset.map(data_augment, num_parallel_calls=AUTO)
    if repeated:
        dataset = dataset.repeat()
    if not ordered:
        dataset = dataset.shuffle(2048)
    dataset = dataset.batch(BATCH_SIZE)
    dataset = dataset.prefetch(AUTO)
    return dataset
import math
np.set_printoptions(threshold=15, linewidth=80)
CLASSES = [0,1]

def batch_to_numpy_images_and_labels(data):
    images, labels = data
    numpy_images = images.numpy()
    numpy_labels = labels.numpy()
    labels = [str(i) for i in  numpy_labels]

    return numpy_images, labels

def title_from_label_and_target(label, correct_label):
    if correct_label is None:
        return CLASSES[label], True
    correct = (label == correct_label)
    return "{} [{}{}{}]".format(CLASSES[label], 'OK' if correct else 'NO', u"\u2192" if not correct else '',
                                CLASSES[correct_label] if not correct else ''), correct

def display_one_flower(image, title, subplot, red=False, titlesize=16):
    plt.subplot(*subplot)
    plt.axis('off')
    plt.imshow(image)
    if len(title) > 0:
        plt.title(title, fontsize=int(titlesize) if not red else int(titlesize/1.2), color='red' if red else 'black', fontdict={'verticalalignment':'center'}, pad=int(titlesize/1.5))
    return (subplot[0], subplot[1], subplot[2]+1)
    
def display_batch_of_images(databatch, predictions=None):
    """This will work with:
    display_batch_of_images(images)
    display_batch_of_images(images, predictions)
    display_batch_of_images((images, labels))
    display_batch_of_images((images, labels), predictions)
    """
    # data
    images, labels = batch_to_numpy_images_and_labels(databatch)
    if labels is None:
        labels = [None for _ in enumerate(images)]
        
    # auto-squaring: this will drop data that does not fit into square or square-ish rectangle
    rows = int(math.sqrt(len(images)))
    cols = len(images)//rows
        
    # size and spacing
    FIGSIZE = 10.0
    SPACING = 0.1
    subplot=(rows,cols,1)
    if rows < cols:
        plt.figure(figsize=(FIGSIZE,FIGSIZE/cols*rows))
    else:
        plt.figure(figsize=(FIGSIZE/rows*cols,FIGSIZE))
    
    # display
    for i, (image, label) in enumerate(zip(images[:rows*cols], labels[:rows*cols])):
        title = label
        correct = True
        if predictions is not None:
            title, correct = title_from_label_and_target(predictions[i], label)
        dynamic_titlesize = FIGSIZE*SPACING/max(rows,cols)*40+3 # magic formula tested to work from 1x1 to 10x10 images
        # image = cv2.imdecode(image,cv2.IMREA)
        subplot = display_one_flower(image, title, subplot, not correct, titlesize=dynamic_titlesize)
    
    #layout
    plt.tight_layout()
    if label is None and predictions is None:
        plt.subplots_adjust(wspace=0, hspace=0)
    else:
        plt.subplots_adjust(wspace=SPACING, hspace=SPACING)
    
    
# Model evaluation
def plot_metrics(history):
    metric_list = [m for m in list(history.keys()) if m is not 'lr']
    size = len(metric_list)//2
    fig, axes = plt.subplots(size, 1, sharex='col', figsize=(10, size * 4))
    if size > 1:
        axes = axes.flatten()
    else:
        axes = [axes]
    
    for index in range(len(metric_list)//2):
        metric_name = metric_list[index]
        val_metric_name = metric_list[index+size]
        axes[index].plot(history[metric_name], label='Train %s' % metric_name)
        axes[index].plot(history[val_metric_name], label='Validation %s' % metric_name)
        axes[index].legend(loc='best', fontsize=6)#16
        axes[index].set_title(metric_name)
        if 'loss' in metric_name:
            axes[index].axvline(np.argmin(history[metric_name]), linestyle='dashed')
            axes[index].axvline(np.argmin(history[val_metric_name]), linestyle='dashed', color='orange')
        else:
            axes[index].axvline(np.argmax(history[metric_name]), linestyle='dashed')
            axes[index].axvline(np.argmax(history[val_metric_name]), linestyle='dashed', color='orange')

    plt.xlabel('Epochs', fontsize=16)
    sns.despine()
    plt.show()

# %%
train_dataset = get_dataset(FILENAMES[:60],LABELS[:60], ordered=True,augment=True)
train_iter = iter(train_dataset.unbatch().batch(5))

display_batch_of_images(next(train_iter))
display_batch_of_images(next(train_iter))
# Out:
# 2022-11-22 14:17:21.903065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:22.084927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:22.086183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:22.088947: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-22 14:17:22.089582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:22.090677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:22.091647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:25.314772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:25.316071: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:25.317216: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-22 14:17:25.318071: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2022-11-22 14:17:26.824751: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# Cosine Annealing:-
LR_START = 1e-8
LR_MIN = 1e-8
LR_MAX = LEARNING_RATE
LR_RAMPUP_EPOCHS = 3
LR_SUSTAIN_EPOCHS = 0
N_CYCLES = .5


def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        progress = (epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS) / (EPOCHS - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS)
        lr = LR_MAX * (0.5 * (1.0 + tf.math.cos(math.pi * N_CYCLES * 2.0 * progress)))
        if LR_MIN is not None:
            lr = tf.math.maximum(LR_MIN, lr)
            
    return lr

rng = [i for i in range(EPOCHS)]
y = [lrfn(x) for x in rng]

sns.set(style='whitegrid')
fig, ax = plt.subplots(figsize=(10, 6))
plt.plot(rng, y)

# print(f'{EPOCHS} total epochs and {NUM_TRAINING_IMAGES//BATCH_SIZE} steps per epoch')
print(f'Learning rate schedule: {y[0]:.3g} to {max(y):.3g} to {y[-1]:.3g}')
# Out:
# Learning rate schedule: 1e-08 to 0.003 to 8.79e-06

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dropout,Flatten,Dense,BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %%
#def model_fn(input_shape, N_CLASSES):
model = Sequential()
model.add(Conv2D(16,(3,3),activation='relu',input_shape=(300,300,3)))
model.add(MaxPool2D(2,2))
#model.add(Dropout(0.2))

model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPool2D(2,2))
#model.add(Dropout(0.3))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPool2D(2,2))#
model.add(Dropout(0.3))


model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPool2D(2,2))
model.add(Dropout(0.3))

model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPool2D(2,2)) 

model.add(Conv2D(512,(3,3),activation='elu'))
model.add(MaxPool2D(2,2))


model.add(Flatten())
model.add(Dense(32,activation='elu'))
model.add(Dropout(0.25))

model.add(Dense(2,activation='softmax'))
    
    
   # return model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 33, 33, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                65568
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 1,638,402
# Trainable params: 1,638,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
import tensorflow_addons as tfa
 #optimizer = optimizers.Adam(lr=LEARNING_RATE)
 #model.compile(optimizer=optimizer, 
                  #loss='binary_crossentropy', 'accuracy','auc'
                  #metrics=['accuracy',tfa.metrics.F1Score(num_classes=2, average='weighted')])  #'acc','AUC'
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy',tfa.metrics.F1Score(num_classes=2, average='weighted')])

# %%
TF_DISABLE_SEGMENT_REDUCTION_OP_DETERMINISM_EXCEPTIONS=True

# %%
# Cross Validated training loop:-
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []
cv1 = cv2 = 0


for fold,(idxT, idxV) in enumerate(skf.split(FILENAMES,LABELS)):
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    STEPS_PER_EPOCH = len(idxT) // BATCH_SIZE
    
    
    K.clear_session()
    
    model_path = f'model_{fold}.h5'
    es = EarlyStopping(monitor='val_f1_score', mode='max', 
                    patience=ES_PATIENCE, restore_best_weights=True, verbose=1)
    
    history = model.fit(x=get_dataset(FILENAMES[idxT],LABELS[idxT], ordered=False, repeated=True, augment=True), 
                        validation_data=get_dataset(FILENAMES[idxV],LABELS[idxV] , ordered=True, repeated=False, augment=False), 
                        steps_per_epoch=STEPS_PER_EPOCH, 
                        callbacks=[LearningRateScheduler(lrfn ,verbose=0)], #es, 
                        epochs=EPOCHS,  
                        verbose=1,
                        class_weight = cw).history
      
    model.save_weights(model_path)
    history_list.append(history)
    
      ## RESULTS
    print(f"#### FOLD {fold+1} Accuracy = {np.max(history['accuracy']):.3f}")#accuracy
    #print(f"#### FOLD {fold+1} AUC = {np.max(history['AUC']):.3f}")
    print(f"#### FOLD {fold+1} F1_score = {np.max(history['f1_score']):.3f}")
    cv1 += np.max(history['accuracy'])
    
    cv2 += np.max(history['f1_score'])
    #cv3+=np.max(history['AUC'])
    
    
print(f'### Avg. Accuracy = {cv1/5.0} \n ### Avg. Weighted F1 = {cv2/5.0}')# \n ### Avg. Weighted AUC = {cv3/5.0}')
# Out:
# FOLD: 1
# TRAIN: 8528 VALID: 2133
# Epoch 1/32
# 2022-11-22 14:17:42.742348: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 786 of 2048
# 2022-11-22 14:17:52.739668: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1700 of 2048
# 2022-11-22 14:17:56.299452: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 2022-11-22 14:17:58.605133: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 266/266 [==============================] - 142s 402ms/step - loss: 0.6948 - accuracy: 0.6453 - f1_score: 0.5712 - val_loss: 0.6891 - val_accuracy: 0.6821 - val_f1_score: 0.5532
# Epoch 2/32
# 266/266 [==============================] - 96s 361ms/step - loss: 0.6308 - accuracy: 0.6519 - f1_score: 0.6614 - val_loss: 0.5106 - val_accuracy: 0.7792 - val_f1_score: 0.7811
# Epoch 3/32
# 266/266 [==============================] - 70s 265ms/step - loss: 0.6213 - accuracy: 0.6836 - f1_score: 0.6900 - val_loss: 0.5217 - val_accuracy: 0.7989 - val_f1_score: 0.7943
# Epoch 4/32
# 266/266 [==============================] - 67s 251ms/step - loss: 0.6034 - accuracy: 0.6949 - f1_score: 0.7003 - val_loss: 0.4931 - val_accuracy: 0.7904 - val_f1_score: 0.7901
# Epoch 5/32
# 266/266 [==============================] - 74s 280ms/step - loss: 0.5934 - accuracy: 0.7055 - f1_score: 0.7112 - val_loss: 0.4803 - val_accuracy: 0.7923 - val_f1_score: 0.7873
# Epoch 6/32
# 266/266 [==============================] - 80s 300ms/step - loss: 0.5890 - accuracy: 0.7170 - f1_score: 0.7213 - val_loss: 0.4884 - val_accuracy: 0.7975 - val_f1_score: 0.7957
# Epoch 7/32
# 266/266 [==============================] - 62s 234ms/step - loss: 0.5764 - accuracy: 0.7246 - f1_score: 0.7292 - val_loss: 0.5291 - val_accuracy: 0.7736 - val_f1_score: 0.7778
# Epoch 8/32
# 266/266 [==============================] - 70s 265ms/step - loss: 0.5622 - accuracy: 0.7339 - f1_score: 0.7383 - val_loss: 0.5127 - val_accuracy: 0.7825 - val_f1_score: 0.7834
# Epoch 9/32
# 266/266 [==============================] - 72s 270ms/step - loss: 0.5544 - accuracy: 0.7398 - f1_score: 0.7444 - val_loss: 0.5300 - val_accuracy: 0.7829 - val_f1_score: 0.7864
# Epoch 10/32
# 266/266 [==============================] - 71s 267ms/step - loss: 0.5543 - accuracy: 0.7385 - f1_score: 0.7433 - val_loss: 0.5533 - val_accuracy: 0.7567 - val_f1_score: 0.7639
# Epoch 11/32
# 266/266 [==============================] - 71s 269ms/step - loss: 0.5634 - accuracy: 0.7412 - f1_score: 0.7449 - val_loss: 0.4973 - val_accuracy: 0.7876 - val_f1_score: 0.7900
# Epoch 12/32
# 266/266 [==============================] - 71s 269ms/step - loss: 0.5498 - accuracy: 0.7434 - f1_score: 0.7477 - val_loss: 0.5237 - val_accuracy: 0.7651 - val_f1_score: 0.7710
# Epoch 13/32
# 266/266 [==============================] - 75s 283ms/step - loss: 0.5474 - accuracy: 0.7549 - f1_score: 0.7587 - val_loss: 0.4657 - val_accuracy: 0.7923 - val_f1_score: 0.7924
# Epoch 14/32
# 266/266 [==============================] - 82s 310ms/step - loss: 0.5412 - accuracy: 0.7477 - f1_score: 0.7518 - val_loss: 0.6155 - val_accuracy: 0.7196 - val_f1_score: 0.7293
# Epoch 15/32
# 266/266 [==============================] - 82s 311ms/step - loss: 0.5386 - accuracy: 0.7513 - f1_score: 0.7557 - val_loss: 0.4637 - val_accuracy: 0.8031 - val_f1_score: 0.8005
# Epoch 16/32
# 266/266 [==============================] - 76s 285ms/step - loss: 0.5422 - accuracy: 0.7498 - f1_score: 0.7536 - val_loss: 0.4697 - val_accuracy: 0.7890 - val_f1_score: 0.7910
# Epoch 17/32
# 266/266 [==============================] - 78s 293ms/step - loss: 0.5374 - accuracy: 0.7543 - f1_score: 0.7583 - val_loss: 0.5040 - val_accuracy: 0.7829 - val_f1_score: 0.7858
# Epoch 18/32
# 266/266 [==============================] - 72s 272ms/step - loss: 0.5303 - accuracy: 0.7641 - f1_score: 0.7674 - val_loss: 0.5200 - val_accuracy: 0.7609 - val_f1_score: 0.7667
# Epoch 19/32
# 266/266 [==============================] - 73s 274ms/step - loss: 0.5208 - accuracy: 0.7708 - f1_score: 0.7735 - val_loss: 0.4949 - val_accuracy: 0.7862 - val_f1_score: 0.7885
# Epoch 20/32
# 266/266 [==============================] - 76s 287ms/step - loss: 0.5281 - accuracy: 0.7710 - f1_score: 0.7730 - val_loss: 0.4949 - val_accuracy: 0.7918 - val_f1_score: 0.7927
# Epoch 21/32
# 266/266 [==============================] - 70s 266ms/step - loss: 0.5216 - accuracy: 0.7750 - f1_score: 0.7775 - val_loss: 0.5059 - val_accuracy: 0.7693 - val_f1_score: 0.7749
# Epoch 22/32
# 266/266 [==============================] - 76s 288ms/step - loss: 0.5213 - accuracy: 0.7715 - f1_score: 0.7738 - val_loss: 0.5056 - val_accuracy: 0.7820 - val_f1_score: 0.7847
# Epoch 23/32
# 266/266 [==============================] - 67s 254ms/step - loss: 0.5017 - accuracy: 0.7856 - f1_score: 0.7877 - val_loss: 0.4578 - val_accuracy: 0.7970 - val_f1_score: 0.7967
# Epoch 24/32
# 266/266 [==============================] - 79s 298ms/step - loss: 0.5071 - accuracy: 0.7798 - f1_score: 0.7816 - val_loss: 0.4695 - val_accuracy: 0.7937 - val_f1_score: 0.7957
# Epoch 25/32
# 266/266 [==============================] - 71s 268ms/step - loss: 0.5064 - accuracy: 0.7811 - f1_score: 0.7837 - val_loss: 0.4506 - val_accuracy: 0.7965 - val_f1_score: 0.7972
# Epoch 26/32
# 266/266 [==============================] - 76s 287ms/step - loss: 0.5074 - accuracy: 0.7825 - f1_score: 0.7847 - val_loss: 0.4520 - val_accuracy: 0.7998 - val_f1_score: 0.8005
# Epoch 27/32
# 266/266 [==============================] - 74s 279ms/step - loss: 0.5029 - accuracy: 0.7858 - f1_score: 0.7877 - val_loss: 0.4700 - val_accuracy: 0.7942 - val_f1_score: 0.7965
# Epoch 28/32
# 266/266 [==============================] - 81s 305ms/step - loss: 0.4948 - accuracy: 0.7890 - f1_score: 0.7908 - val_loss: 0.4332 - val_accuracy: 0.8045 - val_f1_score: 0.8030
# Epoch 29/32
# 266/266 [==============================] - 72s 273ms/step - loss: 0.4990 - accuracy: 0.7837 - f1_score: 0.7862 - val_loss: 0.4467 - val_accuracy: 0.7989 - val_f1_score: 0.7993
# Epoch 30/32
# 266/266 [==============================] - 90s 339ms/step - loss: 0.4982 - accuracy: 0.7874 - f1_score: 0.7891 - val_loss: 0.4449 - val_accuracy: 0.7993 - val_f1_score: 0.7993
# Epoch 31/32
# 266/266 [==============================] - 89s 337ms/step - loss: 0.4910 - accuracy: 0.7894 - f1_score: 0.7914 - val_loss: 0.4433 - val_accuracy: 0.7998 - val_f1_score: 0.7997
# Epoch 32/32
# 266/266 [==============================] - 83s 314ms/step - loss: 0.4915 - accuracy: 0.7949 - f1_score: 0.7964 - val_loss: 0.4434 - val_accuracy: 0.7993 - val_f1_score: 0.7993
# #### FOLD 1 Accuracy = 0.795
# #### FOLD 1 F1_score = 0.796
#
# FOLD: 2
# TRAIN: 8529 VALID: 2132
# Epoch 1/32
# 2022-11-22 14:59:12.986239: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1292 of 2048
# 2022-11-22 14:59:17.280923: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 266/266 [==============================] - 109s 354ms/step - loss: 0.5049 - accuracy: 0.7783 - f1_score: 0.7804 - val_loss: 0.4273 - val_accuracy: 0.8213 - val_f1_score: 0.8214
# Epoch 2/32
# 266/266 [==============================] - 88s 333ms/step - loss: 0.5045 - accuracy: 0.7847 - f1_score: 0.7869 - val_loss: 0.4321 - val_accuracy: 0.8288 - val_f1_score: 0.8269
# Epoch 3/32
# 266/266 [==============================] - 98s 371ms/step - loss: 0.5210 - accuracy: 0.7757 - f1_score: 0.7778 - val_loss: 0.4322 - val_accuracy: 0.8316 - val_f1_score: 0.8258
# Epoch 4/32
# 266/266 [==============================] - 97s 365ms/step - loss: 0.5448 - accuracy: 0.7598 - f1_score: 0.7616 - val_loss: 0.4642 - val_accuracy: 0.8124 - val_f1_score: 0.8137
# Epoch 5/32
# 266/266 [==============================] - 97s 368ms/step - loss: 0.5337 - accuracy: 0.7636 - f1_score: 0.7658 - val_loss: 0.4663 - val_accuracy: 0.7946 - val_f1_score: 0.7985
# Epoch 6/32
# 266/266 [==============================] - 140s 526ms/step - loss: 0.5459 - accuracy: 0.7572 - f1_score: 0.7596 - val_loss: 0.4499 - val_accuracy: 0.8250 - val_f1_score: 0.8177
# Epoch 7/32
# 266/266 [==============================] - 103s 390ms/step - loss: 0.5387 - accuracy: 0.7574 - f1_score: 0.7607 - val_loss: 0.5018 - val_accuracy: 0.8236 - val_f1_score: 0.8246
# Epoch 8/32
# 266/266 [==============================] - 98s 369ms/step - loss: 0.5262 - accuracy: 0.7676 - f1_score: 0.7700 - val_loss: 0.5172 - val_accuracy: 0.7613 - val_f1_score: 0.7690
# Epoch 9/32
# 266/266 [==============================] - 100s 376ms/step - loss: 0.5316 - accuracy: 0.7673 - f1_score: 0.7698 - val_loss: 0.4720 - val_accuracy: 0.7992 - val_f1_score: 0.8031
# Epoch 10/32
# 266/266 [==============================] - 85s 320ms/step - loss: 0.5281 - accuracy: 0.7696 - f1_score: 0.7723 - val_loss: 0.4709 - val_accuracy: 0.8016 - val_f1_score: 0.8052
# Epoch 11/32
# 266/266 [==============================] - 86s 324ms/step - loss: 0.5301 - accuracy: 0.7635 - f1_score: 0.7651 - val_loss: 0.5059 - val_accuracy: 0.8157 - val_f1_score: 0.8175
# Epoch 12/32
# 266/266 [==============================] - 91s 343ms/step - loss: 0.5189 - accuracy: 0.7727 - f1_score: 0.7739 - val_loss: 0.4192 - val_accuracy: 0.8349 - val_f1_score: 0.8299
# Epoch 13/32
# 266/266 [==============================] - 89s 337ms/step - loss: 0.5266 - accuracy: 0.7793 - f1_score: 0.7804 - val_loss: 0.4688 - val_accuracy: 0.7899 - val_f1_score: 0.7952
# Epoch 14/32
# 266/266 [==============================] - 88s 332ms/step - loss: 0.5197 - accuracy: 0.7753 - f1_score: 0.7768 - val_loss: 0.5226 - val_accuracy: 0.7720 - val_f1_score: 0.7784
# Epoch 15/32
# 266/266 [==============================] - 77s 289ms/step - loss: 0.5246 - accuracy: 0.7744 - f1_score: 0.7761 - val_loss: 0.5106 - val_accuracy: 0.7598 - val_f1_score: 0.7675
# Epoch 16/32
# 266/266 [==============================] - 89s 334ms/step - loss: 0.5141 - accuracy: 0.7784 - f1_score: 0.7805 - val_loss: 0.4710 - val_accuracy: 0.8279 - val_f1_score: 0.8273
# Epoch 17/32
# 266/266 [==============================] - 85s 322ms/step - loss: 0.5132 - accuracy: 0.7802 - f1_score: 0.7817 - val_loss: 0.4410 - val_accuracy: 0.8326 - val_f1_score: 0.8307
# Epoch 18/32
# 266/266 [==============================] - 96s 362ms/step - loss: 0.5086 - accuracy: 0.7817 - f1_score: 0.7833 - val_loss: 0.4263 - val_accuracy: 0.8368 - val_f1_score: 0.8343
# Epoch 19/32
# 266/266 [==============================] - 92s 345ms/step - loss: 0.4972 - accuracy: 0.7869 - f1_score: 0.7887 - val_loss: 0.4561 - val_accuracy: 0.7955 - val_f1_score: 0.8004
# Epoch 20/32
# 266/266 [==============================] - 87s 327ms/step - loss: 0.5063 - accuracy: 0.7887 - f1_score: 0.7895 - val_loss: 0.4615 - val_accuracy: 0.7988 - val_f1_score: 0.8027
# Epoch 21/32
# 266/266 [==============================] - 85s 319ms/step - loss: 0.4978 - accuracy: 0.7878 - f1_score: 0.7895 - val_loss: 0.4288 - val_accuracy: 0.8288 - val_f1_score: 0.8297
# Epoch 22/32
# 266/266 [==============================] - 90s 338ms/step - loss: 0.4976 - accuracy: 0.7897 - f1_score: 0.7908 - val_loss: 0.4047 - val_accuracy: 0.8438 - val_f1_score: 0.8429
# Epoch 23/32
# 266/266 [==============================] - 86s 326ms/step - loss: 0.5004 - accuracy: 0.7871 - f1_score: 0.7884 - val_loss: 0.4218 - val_accuracy: 0.8452 - val_f1_score: 0.8428
# Epoch 24/32
# 266/266 [==============================] - 88s 331ms/step - loss: 0.4893 - accuracy: 0.7976 - f1_score: 0.7990 - val_loss: 0.4644 - val_accuracy: 0.7917 - val_f1_score: 0.7971
# Epoch 25/32
# 266/266 [==============================] - 85s 321ms/step - loss: 0.4813 - accuracy: 0.7962 - f1_score: 0.7973 - val_loss: 0.4484 - val_accuracy: 0.8185 - val_f1_score: 0.8220
# Epoch 26/32
# 266/266 [==============================] - 84s 317ms/step - loss: 0.4865 - accuracy: 0.7937 - f1_score: 0.7954 - val_loss: 0.4220 - val_accuracy: 0.8377 - val_f1_score: 0.8385
# Epoch 27/32
# 266/266 [==============================] - 85s 320ms/step - loss: 0.4841 - accuracy: 0.7943 - f1_score: 0.7954 - val_loss: 0.4318 - val_accuracy: 0.8213 - val_f1_score: 0.8237
# Epoch 28/32
# 266/266 [==============================] - 88s 331ms/step - loss: 0.4800 - accuracy: 0.7990 - f1_score: 0.8000 - val_loss: 0.4276 - val_accuracy: 0.8269 - val_f1_score: 0.8292
# Epoch 29/32
# 266/266 [==============================] - 85s 319ms/step - loss: 0.4774 - accuracy: 0.8010 - f1_score: 0.8026 - val_loss: 0.4296 - val_accuracy: 0.8255 - val_f1_score: 0.8280
# Epoch 30/32
# 266/266 [==============================] - 88s 332ms/step - loss: 0.4776 - accuracy: 0.8017 - f1_score: 0.8023 - val_loss: 0.4224 - val_accuracy: 0.8311 - val_f1_score: 0.8331
# Epoch 31/32
# 266/266 [==============================] - 85s 322ms/step - loss: 0.4793 - accuracy: 0.8008 - f1_score: 0.8015 - val_loss: 0.4257 - val_accuracy: 0.8326 - val_f1_score: 0.8345
# Epoch 32/32
# 266/266 [==============================] - 90s 341ms/step - loss: 0.4704 - accuracy: 0.8059 - f1_score: 0.8069 - val_loss: 0.4246 - val_accuracy: 0.8326 - val_f1_score: 0.8345
# #### FOLD 2 Accuracy = 0.806
# #### FOLD 2 F1_score = 0.807
#
# FOLD: 3
# TRAIN: 8529 VALID: 2132
# Epoch 1/32
# 2022-11-22 15:48:36.633699: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1125 of 2048
# 2022-11-22 15:48:43.695054: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 266/266 [==============================] - 104s 323ms/step - loss: 0.4823 - accuracy: 0.8036 - f1_score: 0.8040 - val_loss: 0.4254 - val_accuracy: 0.8185 - val_f1_score: 0.8208
# Epoch 2/32
# 266/266 [==============================] - 61s 229ms/step - loss: 0.4886 - accuracy: 0.7979 - f1_score: 0.7984 - val_loss: 0.4302 - val_accuracy: 0.8218 - val_f1_score: 0.8233
# Epoch 3/32
# 266/266 [==============================] - 55s 209ms/step - loss: 0.4997 - accuracy: 0.7874 - f1_score: 0.7888 - val_loss: 0.4680 - val_accuracy: 0.8021 - val_f1_score: 0.8061
# Epoch 4/32
# 266/266 [==============================] - 56s 210ms/step - loss: 0.5129 - accuracy: 0.7807 - f1_score: 0.7816 - val_loss: 0.4736 - val_accuracy: 0.8189 - val_f1_score: 0.8195
# Epoch 5/32
# 266/266 [==============================] - 57s 215ms/step - loss: 0.5186 - accuracy: 0.7777 - f1_score: 0.7786 - val_loss: 0.4164 - val_accuracy: 0.8368 - val_f1_score: 0.8358
# Epoch 6/32
# 266/266 [==============================] - 58s 220ms/step - loss: 0.5211 - accuracy: 0.7789 - f1_score: 0.7796 - val_loss: 0.4363 - val_accuracy: 0.8119 - val_f1_score: 0.8145
# Epoch 7/32
# 266/266 [==============================] - 58s 220ms/step - loss: 0.5197 - accuracy: 0.7753 - f1_score: 0.7769 - val_loss: 0.4283 - val_accuracy: 0.8110 - val_f1_score: 0.8140
# Epoch 8/32
# 266/266 [==============================] - 56s 209ms/step - loss: 0.5172 - accuracy: 0.7801 - f1_score: 0.7815 - val_loss: 0.4534 - val_accuracy: 0.8175 - val_f1_score: 0.8007
# Epoch 9/32
# 266/266 [==============================] - 59s 222ms/step - loss: 0.5326 - accuracy: 0.7650 - f1_score: 0.7666 - val_loss: 0.4073 - val_accuracy: 0.8335 - val_f1_score: 0.8278
# Epoch 10/32
# 266/266 [==============================] - 57s 214ms/step - loss: 0.5154 - accuracy: 0.7856 - f1_score: 0.7864 - val_loss: 0.4485 - val_accuracy: 0.8222 - val_f1_score: 0.8227
# Epoch 11/32
# 266/266 [==============================] - 61s 230ms/step - loss: 0.5057 - accuracy: 0.7808 - f1_score: 0.7819 - val_loss: 0.4575 - val_accuracy: 0.7997 - val_f1_score: 0.8045
# Epoch 12/32
# 266/266 [==============================] - 70s 264ms/step - loss: 0.4959 - accuracy: 0.7918 - f1_score: 0.7931 - val_loss: 0.6822 - val_accuracy: 0.6571 - val_f1_score: 0.6659
# Epoch 13/32
# 266/266 [==============================] - 59s 223ms/step - loss: 0.5018 - accuracy: 0.7882 - f1_score: 0.7891 - val_loss: 0.4595 - val_accuracy: 0.8194 - val_f1_score: 0.8227
# Epoch 14/32
# 266/266 [==============================] - 63s 237ms/step - loss: 0.4936 - accuracy: 0.7896 - f1_score: 0.7913 - val_loss: 0.3784 - val_accuracy: 0.8485 - val_f1_score: 0.8454
# Epoch 15/32
# 266/266 [==============================] - 62s 235ms/step - loss: 0.4855 - accuracy: 0.7995 - f1_score: 0.8008 - val_loss: 0.3838 - val_accuracy: 0.8447 - val_f1_score: 0.8379
# Epoch 16/32
# 266/266 [==============================] - 61s 228ms/step - loss: 0.4617 - accuracy: 0.8063 - f1_score: 0.8080 - val_loss: 0.3858 - val_accuracy: 0.8607 - val_f1_score: 0.8575
# Epoch 17/32
# 266/266 [==============================] - 61s 231ms/step - loss: 0.4602 - accuracy: 0.8110 - f1_score: 0.8126 - val_loss: 0.4002 - val_accuracy: 0.8391 - val_f1_score: 0.8411
# Epoch 18/32
# 266/266 [==============================] - 60s 226ms/step - loss: 0.4517 - accuracy: 0.8139 - f1_score: 0.8154 - val_loss: 0.4191 - val_accuracy: 0.8377 - val_f1_score: 0.8365
# Epoch 19/32
# 266/266 [==============================] - 61s 229ms/step - loss: 0.4406 - accuracy: 0.8161 - f1_score: 0.8181 - val_loss: 0.3930 - val_accuracy: 0.8386 - val_f1_score: 0.8371
# Epoch 20/32
# 266/266 [==============================] - 59s 222ms/step - loss: 0.4521 - accuracy: 0.8157 - f1_score: 0.8172 - val_loss: 0.4184 - val_accuracy: 0.8410 - val_f1_score: 0.8426
# Epoch 21/32
# 266/266 [==============================] - 61s 231ms/step - loss: 0.4311 - accuracy: 0.8287 - f1_score: 0.8293 - val_loss: 0.3682 - val_accuracy: 0.8541 - val_f1_score: 0.8540
# Epoch 22/32
# 266/266 [==============================] - 60s 227ms/step - loss: 0.4314 - accuracy: 0.8254 - f1_score: 0.8267 - val_loss: 0.3904 - val_accuracy: 0.8452 - val_f1_score: 0.8462
# Epoch 23/32
# 266/266 [==============================] - 63s 237ms/step - loss: 0.4214 - accuracy: 0.8289 - f1_score: 0.8307 - val_loss: 0.3688 - val_accuracy: 0.8499 - val_f1_score: 0.8445
# Epoch 24/32
# 266/266 [==============================] - 61s 229ms/step - loss: 0.4254 - accuracy: 0.8292 - f1_score: 0.8304 - val_loss: 0.3803 - val_accuracy: 0.8504 - val_f1_score: 0.8449
# Epoch 25/32
# 266/266 [==============================] - 62s 235ms/step - loss: 0.4169 - accuracy: 0.8308 - f1_score: 0.8326 - val_loss: 0.3678 - val_accuracy: 0.8443 - val_f1_score: 0.8430
# Epoch 26/32
# 266/266 [==============================] - 64s 242ms/step - loss: 0.4201 - accuracy: 0.8273 - f1_score: 0.8289 - val_loss: 0.3741 - val_accuracy: 0.8476 - val_f1_score: 0.8401
# Epoch 27/32
# 266/266 [==============================] - 64s 240ms/step - loss: 0.4137 - accuracy: 0.8315 - f1_score: 0.8333 - val_loss: 0.3636 - val_accuracy: 0.8518 - val_f1_score: 0.8471
# Epoch 28/32
# 266/266 [==============================] - 71s 266ms/step - loss: 0.4099 - accuracy: 0.8308 - f1_score: 0.8323 - val_loss: 0.3570 - val_accuracy: 0.8523 - val_f1_score: 0.8505
# Epoch 29/32
# 266/266 [==============================] - 62s 234ms/step - loss: 0.4152 - accuracy: 0.8307 - f1_score: 0.8325 - val_loss: 0.3588 - val_accuracy: 0.8508 - val_f1_score: 0.8490
# Epoch 30/32
# 266/266 [==============================] - 67s 252ms/step - loss: 0.4088 - accuracy: 0.8325 - f1_score: 0.8341 - val_loss: 0.3585 - val_accuracy: 0.8518 - val_f1_score: 0.8488
# Epoch 31/32
# 266/266 [==============================] - 65s 244ms/step - loss: 0.4234 - accuracy: 0.8232 - f1_score: 0.8250 - val_loss: 0.3603 - val_accuracy: 0.8532 - val_f1_score: 0.8507
# Epoch 32/32
# 266/266 [==============================] - 67s 251ms/step - loss: 0.3998 - accuracy: 0.8387 - f1_score: 0.8403 - val_loss: 0.3594 - val_accuracy: 0.8541 - val_f1_score: 0.8514
# #### FOLD 3 Accuracy = 0.839
# #### FOLD 3 F1_score = 0.840
#
# FOLD: 4
# TRAIN: 8529 VALID: 2132
# Epoch 1/32
# 2022-11-22 16:22:01.271361: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:175] Filling up shuffle buffer (this may take a while): 1818 of 2048
# 2022-11-22 16:22:02.820803: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:228] Shuffle buffer filled.
# 266/266 [==============================] - 78s 247ms/step - loss: 0.4108 - accuracy: 0.8361 - f1_score: 0.8376 - val_loss: 0.3433 - val_accuracy: 0.8668 - val_f1_score: 0.8648
# Epoch 2/32
# 266/266 [==============================] - 60s 228ms/step - loss: 0.4275 - accuracy: 0.8228 - f1_score: 0.8249 - val_loss: 0.3842 - val_accuracy: 0.8551 - val_f1_score: 0.8569
# Epoch 3/32
# 266/266 [==============================] - 60s 226ms/step - loss: 0.4549 - accuracy: 0.8220 - f1_score: 0.8231 - val_loss: 0.4201 - val_accuracy: 0.8265 - val_f1_score: 0.8307
# Epoch 4/32
# 266/266 [==============================] - 62s 235ms/step - loss: 0.4649 - accuracy: 0.8102 - f1_score: 0.8115 - val_loss: 0.3650 - val_accuracy: 0.8593 - val_f1_score: 0.8545
# Epoch 5/32
# 266/266 [==============================] - 64s 240ms/step - loss: 0.4786 - accuracy: 0.7976 - f1_score: 0.7988 - val_loss: 0.3818 - val_accuracy: 0.8649 - val_f1_score: 0.8632
# Epoch 6/32
# 266/266 [==============================] - 64s 240ms/step - loss: 0.4579 - accuracy: 0.8120 - f1_score: 0.8131 - val_loss: 0.3763 - val_accuracy: 0.8555 - val_f1_score: 0.8455
# Epoch 7/32
# 266/266 [==============================] - 63s 237ms/step - loss: 0.4785 - accuracy: 0.7995 - f1_score: 0.8012 - val_loss: 0.5404 - val_accuracy: 0.7692 - val_f1_score: 0.7762
# Epoch 8/32
# 266/266 [==============================] - 64s 242ms/step - loss: 0.4740 - accuracy: 0.8039 - f1_score: 0.8053 - val_loss: 0.3662 - val_accuracy: 0.8569 - val_f1_score: 0.8573
# Epoch 9/32
# 266/266 [==============================] - 68s 255ms/step - loss: 0.4763 - accuracy: 0.8080 - f1_score: 0.8084 - val_loss: 0.3798 - val_accuracy: 0.8485 - val_f1_score: 0.8382
# Epoch 10/32
# 266/266 [==============================] - 69s 259ms/step - loss: 0.4624 - accuracy: 0.8109 - f1_score: 0.8120 - val_loss: 0.3689 - val_accuracy: 0.8410 - val_f1_score: 0.8286
# Epoch 11/32
# 266/266 [==============================] - 68s 258ms/step - loss: 0.4508 - accuracy: 0.8186 - f1_score: 0.8193 - val_loss: 0.3787 - val_accuracy: 0.8551 - val_f1_score: 0.8549
# Epoch 12/32
# 266/266 [==============================] - 61s 230ms/step - loss: 0.4520 - accuracy: 0.8180 - f1_score: 0.8189 - val_loss: 0.3956 - val_accuracy: 0.8555 - val_f1_score: 0.8524
# Epoch 13/32
# 266/266 [==============================] - 63s 238ms/step - loss: 0.4451 - accuracy: 0.8218 - f1_score: 0.8228 - val_loss: 0.3695 - val_accuracy: 0.8621 - val_f1_score: 0.8623
# Epoch 14/32
# 266/266 [==============================] - 58s 218ms/step - loss: 0.4402 - accuracy: 0.8232 - f1_score: 0.8239 - val_loss: 0.3741 - val_accuracy: 0.8630 - val_f1_score: 0.8633
# Epoch 15/32
# 266/266 [==============================] - 63s 237ms/step - loss: 0.4501 - accuracy: 0.8179 - f1_score: 0.8189 - val_loss: 0.3785 - val_accuracy: 0.8626 - val_f1_score: 0.8614
# Epoch 16/32
# 266/266 [==============================] - 62s 232ms/step - loss: 0.4315 - accuracy: 0.8320 - f1_score: 0.8324 - val_loss: 0.4143 - val_accuracy: 0.8372 - val_f1_score: 0.8405
# Epoch 17/32
# 266/266 [==============================] - 61s 229ms/step - loss: 0.4338 - accuracy: 0.8259 - f1_score: 0.8268 - val_loss: 0.3419 - val_accuracy: 0.8748 - val_f1_score: 0.8709
# Epoch 18/32
# 266/266 [==============================] - 61s 229ms/step - loss: 0.4264 - accuracy: 0.8264 - f1_score: 0.8276 - val_loss: 0.3368 - val_accuracy: 0.8691 - val_f1_score: 0.8651
# Epoch 19/32
# 266/266 [==============================] - 59s 223ms/step - loss: 0.4177 - accuracy: 0.8398 - f1_score: 0.8405 - val_loss: 0.3420 - val_accuracy: 0.8635 - val_f1_score: 0.8603
# Epoch 20/32
# 266/266 [==============================] - 60s 226ms/step - loss: 0.4152 - accuracy: 0.8327 - f1_score: 0.8342 - val_loss: 0.3868 - val_accuracy: 0.8391 - val_f1_score: 0.8419
# Epoch 21/32
# 266/266 [==============================] - 61s 230ms/step - loss: 0.4057 - accuracy: 0.8368 - f1_score: 0.8379 - val_loss: 0.3343 - val_accuracy: 0.8691 - val_f1_score: 0.8687
# Epoch 22/32
# 266/266 [==============================] - 62s 232ms/step - loss: 0.4044 - accuracy: 0.8419 - f1_score: 0.8430 - val_loss: 0.3292 - val_accuracy: 0.8738 - val_f1_score: 0.8727
# Epoch 23/32
# 266/266 [==============================] - 59s 221ms/step - loss: 0.3918 - accuracy: 0.8419 - f1_score: 0.8430 - val_loss: 0.3476 - val_accuracy: 0.8701 - val_f1_score: 0.8676
# Epoch 24/32
# 238/266 [=========================>....] - ETA: 5s - loss: 0.3886 - accuracy: 0.8490 - f1_score: 0.8496

# %%
# Plot metrics:-
for fold, history in enumerate(history_list):
    print(f'\nFOLD: {fold+1}')
    plot_metrics(history)

# %%
# Include Validation data as well :-
test_data=pd.read_csv(GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data_labels.csv')

at = test_data[test_data['labels'] == 1]
ht = test_data[test_data['labels'] == 0]

test_PATH = GCS_PATH + '/C-NMC_Leukemia/validation_data/C-NMC_test_prelim_phase_data/'
ATL = [test_PATH +  i for i in list(at.new_names)]
HTL = [test_PATH +  i for i in list(ht.new_names)]

# %%
TA=[]
TH=[]

TA.extend(ATL)
TH.extend(HTL)

print(len(TA))
print(len(TH))

# Create labels :-
Label_TA = [1]*len(TA)
Label_TH = [0]*len(TH)

# Converting to pandas dataframe for easier access:-
TA.extend(TH)
Label_TA.extend(Label_TH)
tdf = pd.DataFrame({'path':TA, 'label':Label_TA})
tdf = tdf.sample(frac=1).reset_index(drop=True)
TFILENAMES = tdf['path']
TLABELS = tdf['label']


print('Test Merged Data:-')
tdf

# %%
test_dataset = get_dataset(TFILENAMES[:1867],TLABELS[:1867], ordered=True,augment=True)
test_iter = iter(train_dataset.unbatch().batch(20))

display_batch_of_images(next(test_iter))

# %%
accu = model.evaluate(test_dataset)

# %%
test_x=test_data

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import numpy as np

# %%
#predict
y_pred=model.predict(test_x)
y_pred=np.argmax(y_pred,axis=1)

# %%
#get classification report
print(classification_report(y_pred,test_y))

# %%
print(confusion_matrix(y_pred,test_y))

# %%
# Cross Validated training loop:-
"""skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=seed)
oof_pred = []; oof_labels = []; history_list = []
cv1 = cv2 = 0


for fold,(idxT, idxV) in enumerate(skf.split(FILENAMES,LABELS)):
    print(f'\nFOLD: {fold+1}')
    print(f'TRAIN: {len(idxT)} VALID: {len(idxV)}')
    STEPS_PER_EPOCH = len(idxT) // BATCH_SIZE
    
    
    K.clear_session()
    with strategy.scope():
        #model = model_fn((None, None, CHANNELS), 2)
        
    #model_path = f'model_{fold}.h5'
        es = EarlyStopping(monitor='val_f1_score', mode='max', 
                    patience=ES_PATIENCE, restore_best_weights=True, verbose=1)

    ## TRAIN
        history = model.fit(x=get_dataset(FILENAMES[idxT],LABELS[idxT], ordered=False, repeated=True, augment=True), 
                        validation_data=get_dataset(FILENAMES[idxV],LABELS[idxV] , ordered=True, repeated=False, augment=False), 
                        steps_per_epoch=STEPS_PER_EPOCH, 
                        callbacks=[es, LearningRateScheduler(lrfn ,verbose=0)], 
                        epochs=EPOCHS,  
                        verbose=1,
                        class_weight = cw).history
      
    model.save_weights(model_path)
    history_list.append(history)
    
"""

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
AUC = history.history['auc']
val_AUC = history.history['val_auc']

epochs = range(1,len(acc)+1)

plt.figure()
plt.plot(epochs, acc, 'b', label = 'Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.ylim([0, 1.3])
plt.savefig('Accuracy.png')

plt.figure()
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.ylim([0, 1.3])
plt.savefig('Loss.png')

plt.figure()
plt.plot(epochs, AUC, 'b', label = 'Training AUC')
plt.plot(epochs, val_AUC, 'r', label='Validation AUC')
plt.title('Training and validation AUC')
plt.legend()
plt.ylim([0, 1.3])
plt.savefig('AUC.png')
